// %%
#include <iostream>
using namespace std;

int days;


cout<<"Enter the number of days: ";
cin >>days;

//operation to calculate number of seconds from nujmber of days
int seconds=days*24*60*60;

cout<<"Number of seconds in "<<days<<" days is "<<seconds<<" seconds";

return 0;
// Out:
// Enter the number of days:
//  5
// Number of seconds in 5 days is 432000 seconds
