// %%
int perimeter(int side) {
    return side * 4;
}

// %%
int area(int side){
    return side * side;
}

// %%
#include <iostream>
using namespace std;

int side;

cout<<"Enter side of square: ";
cin>>side
